# %%
import numpy as np
import pandas as pd
from copy import copy
from collections import (namedtuple, defaultdict)
import matplotlib.pyplot as plt
from StaticModelAdaptive import StaticModel
from PolicyAdaptive import Policy

# %%
seed = 89720123
#reading parameter file and initializing variables
file = '/home/peyman/Documents/PhD_UiS/seqdec_powell_repo/Chap5_Sto_Short_Path_Static/function/Parameters.xlsx'
parDf = pd.read_excel(file, sheet_name = 'parameters')
parDict=parDf.set_index('Index').T.to_dict('list')
print("Starting adaptive stochastic shortest path with parameters")
params = {key:v for key, value in parDict.items() for v in value}
params
# Out:
# Starting adaptive stochastic shortest path with parameters
# {'nNodes': 150,
#  'probEdge': 2,
#  'LO_UPPER_BOUND': 10,
#  'HI_UPPER_BOUND': 20,
#  'nIterations': 100,
#  'stepsize_rule': 'Constant',
#  'theta_set': '1 .5 .2 .1'}

# %%
params.update({'seed':seed})
print(params)
# Out:
# {'nNodes': 150, 'probEdge': 2, 'LO_UPPER_BOUND': 10, 'HI_UPPER_BOUND': 20, 'nIterations': 100, 'stepsize_rule': 'Constant', 'theta_set': '1 .5 .2 .1', 'seed': 89720123}

# %%
state_names = ['CurrentNode', 'CurrentNodeLinksCost']
decision_names = ['NextNode']

# %%
# create the model, given the above policy
M = StaticModel(state_names, decision_names,  params)
policy_names = ['PureExploitation']
P = Policy(M, policy_names)
    
theta_list = M.init_args['theta_set'].split()
obj_along_iterations = {theta:[] for theta in theta_list}
vbar_along_iterations = {theta:[] for theta in theta_list}
# Out:
# Created the graph
# max_origin_node: 1 -  max_target_node: 109  - distance: 10
# Computed V_0
# 		key_0 = 44.03
# 		key_1 = 47.33
# 		key_2 = 54.90
# 		key_3 = 46.35
# 		key_4 = 38.92
# 		key_5 = 40.27
# 		key_6 = 33.54
# 		key_7 = 45.82
# 		key_8 = 49.18
# 		key_9 = 46.90
# 		key_10 = 47.37
# 		key_11 = 40.19
# 		key_12 = 30.16
# 		key_13 = 52.82
# 		key_14 = 48.15
# 		key_15 = 45.75
# 		key_16 = 40.77
# 		key_17 = 37.48
# 		key_18 = 60.67
# 		key_19 = 59.97
# 		key_20 = 56.98
# 		key_21 = 51.84
# 		key_22 = 40.74
# 		key_23 = 48.17
# 		key_24 = 43.72
# 		key_25 = 34.85
# 		key_26 = 27.55
# 		key_27 = 24.02
# 		key_28 = 20.91
# 		key_29 = 54.97
# 		key_30 = 51.99
# 		key_31 = 51.98
# 		key_32 = 44.67
# 		key_33 = 55.60
# 		key_34 = 67.72
# 		key_35 = 58.33
# 		key_36 = 53.58
# 		key_37 = 52.39
# 		key_38 = 42.00
# 		key_39 = 45.48
# 		key_40 = 46.76
# 		key_41 = 48.24
# 		key_42 = 50.41
# 		key_43 = 57.31
# 		key_44 = 46.97
# 		key_45 = 42.24
# 		key_46 = 51.85
# 		key_47 = 39.25
# 		key_48 = 46.67
# 		key_49 = 51.57
# 		key_50 = 48.85
# 		key_51 = 43.64
# 		key_52 = 34.02
# 		key_53 = 32.54
# 		key_54 = 53.37
# 		key_55 = 43.75
# 		key_56 = 37.17
# 		key_57 = 53.79
# 		key_58 = 48.74
# 		key_59 = 48.64
# 		key_60 = 41.08
# 		key_61 = 38.93
# 		key_62 = 51.11
# 		key_63 = 46.11
# 		key_64 = 39.77
# 		key_65 = 30.38
# 		key_66 = 50.27
# 		key_67 = 49.52
# 		key_68 = 46.28
# 		key_69 = 46.00
# 		key_70 = 59.65
# 		key_71 = 51.23
# 		key_72 = 47.25
# 		key_73 = 38.98
# 		key_74 = 28.40
# 		key_75 = 51.16
# 		key_76 = 41.75
# 		key_77 = 52.94
# 		key_78 = 46.65
# 		key_79 = 41.22
# 		key_80 = 29.66
# 		key_81 = 56.53
# 		key_82 = 47.62
# 		key_83 = 43.34
# 		key_84 = 37.07
# 		key_85 = 50.41
# 		key_86 = 49.54
# 		key_87 = 49.77
# 		key_88 = 42.78
# 		key_89 = 32.49
# 		key_90 = 21.01
# 		key_91 = 15.66
# 		key_92 = 45.22
# 		key_93 = 47.07
# 		key_94 = 44.79
# 		key_95 = 40.68
# 		key_96 = 37.07
# 		key_97 = 47.60
# 		key_98 = 41.66
# 		key_99 = 41.99
# 		key_100 = 41.04
# 		key_101 = 36.68
# 		key_102 = 34.42
# 		key_103 = 28.88
# 		key_104 = 35.80
# 		key_105 = 22.74
# 		key_106 = 12.41
# 		key_107 = 11.38
# 		key_108 = 5.68
# 		key_109 = 0.00
# 		key_110 = 54.02
# 		key_111 = 42.04
# 		key_112 = 39.70
# 		key_113 = 43.35
# 		key_114 = 38.40
# 		key_115 = 41.98
# 		key_116 = 30.37
# 		key_117 = 31.21
# 		key_118 = 26.45
# 		key_119 = 35.55
# 		key_120 = 23.44
# 		key_121 = 45.84
# 		key_122 = 38.02
# 		key_123 = 50.87
# 		key_124 = 45.57
# 		key_125 = 55.04
# 		key_126 = 49.90
# 		key_127 = 48.27
# 		key_128 = 52.42
# 		key_129 = 41.27
# 		key_130 = 34.18
# 		key_131 = 28.10
# 		key_132 = 30.86
# 		key_133 = 25.87
# 		key_134 = 49.59
# 		key_135 = 38.83
# 		key_136 = 32.45
# 		key_137 = 43.18
# 		key_138 = 40.75
# 		key_139 = 39.33
# 		key_140 = 37.15
# 		key_141 = 29.53
# 		key_142 = 24.43
# 		key_143 = 50.16
# 		key_144 = 43.44
# 		key_145 = 34.59
# 		key_146 = inf
# 		key_147 = inf
# 		key_148 = inf
# 		key_149 = inf
# None
# Initial State
#  CurrentNode: 1 and costs on its edges:
# 		key_2 = 8.08
# 		key_51 = 4.58
# None

# %%
for theta in theta_list:
    model = copy(M)
    model.theta_step = float(theta)
    model.prng = np.random.RandomState(model.init_args['seed'])
    
    print("************Starting iterations for theta {}".format(model.theta_step))

    for ite in list(range(model.init_args['nIterations'])):
        
        model.obj = 0 
        model.state = model.build_state(model.init_state)
        
        print("\tTheta {}  - Iteration {} - Stepsize {:.2f} - InitState {} - Vbar {:.2f}".format(model.theta_step,model.n,model.alpha(),model.state.CurrentNode,model.V_t[model.state.CurrentNode]))
        
        step = 1
        while model.state.CurrentNode != model.init_args['target_node']:
                # calling policy and choosing a decision
                decision,vhat = P.make_decision(model)
                x = model.build_decision({'NextNode': decision})
                
                print("\t\t Theta {}  - Iteration {} - Step {} - Current State {} - vbar = {:.2f}".format(model.theta_step,model.n,step, model.state.CurrentNode,model.V_t[model.state.CurrentNode]))
                

                # update vfa
                vbar = model.update_VFA(vhat)
                
                # print current state, decision , vhat and new vbar
                #model.print_State()
                print("\t\tDecision={}, vhat {:.2f} and new vbar for current state {:.2f}".format(x[0],vhat,model.V_t[model.state.CurrentNode]))

                # transition to the next state w/ the given decision
                model.transition_fn(x)
                step += 1

        print("Finishing Theta {} and Iteration {} with {} steps. Total cost: {} \n".format(model.theta_step,model.n,step-1,model.obj))
        model.n+=1
        obj_along_iterations[theta].append(model.obj)
        vbar_along_iterations[theta].append(model.V_t[model.origin_node])
# Out:
# ************Starting iterations for theta 1.0
# 	Theta 1.0  - Iteration 1 - Stepsize 1.00 - InitState 1 - Vbar 47.33
# 		 Theta 1.0  - Iteration 1 - Step 1 - Current State 1 - vbar = 47.33
# 		Decision=51, vhat 48.22 and new vbar for current state 48.22
# 		 Theta 1.0  - Iteration 1 - Step 2 - Current State 51 - vbar = 43.64
# 		Decision=52, vhat 45.11 and new vbar for current state 45.11
# 		 Theta 1.0  - Iteration 1 - Step 3 - Current State 52 - vbar = 34.02
# 		Decision=53, vhat 34.19 and new vbar for current state 34.19
# 		 Theta 1.0  - Iteration 1 - Step 4 - Current State 53 - vbar = 32.54
# 		Decision=120, vhat 33.61 and new vbar for current state 33.61
# 		 Theta 1.0  - Iteration 1 - Step 5 - Current State 120 - vbar = 23.44
# 		Decision=28, vhat 22.83 and new vbar for current state 22.83
# 		 Theta 1.0  - Iteration 1 - Step 6 - Current State 28 - vbar = 20.91
# 		Decision=91, vhat 21.19 and new vbar for current state 21.19
# 		 Theta 1.0  - Iteration 1 - Step 7 - Current State 91 - vbar = 15.66
# 		Decision=106, vhat 15.61 and new vbar for current state 15.61
# 		 Theta 1.0  - Iteration 1 - Step 8 - Current State 106 - vbar = 12.41
# 		Decision=107, vhat 12.33 and new vbar for current state 12.33
# 		 Theta 1.0  - Iteration 1 - Step 9 - Current State 107 - vbar = 11.38
# 		Decision=108, vhat 12.10 and new vbar for current state 12.10
# 		 Theta 1.0  - Iteration 1 - Step 10 - Current State 108 - vbar = 5.68
# 		Decision=109, vhat 4.01 and new vbar for current state 4.01
# Finishing Theta 1.0 and Iteration 1 with 10 steps. Total cost: 49.510959480969404
#
# 	Theta 1.0  - Iteration 2 - Stepsize 1.00 - InitState 1 - Vbar 48.22
# 		 Theta 1.0  - Iteration 2 - Step 1 - Current State 1 - vbar = 48.22
# 		Decision=51, vhat 49.69 and new vbar for current state 49.69
# 		 Theta 1.0  - Iteration 2 - Step 2 - Current State 51 - vbar = 45.11
# 		Decision=52, vhat 44.42 and new vbar for current state 44.42
# 		 Theta 1.0  - Iteration 2 - Step 3 - Current State 52 - vbar = 34.19
# 		Decision=53, vhat 34.27 and new vbar for current state 34.27
# 		 Theta 1.0  - Iteration 2 - Step 4 - Current State 53 - vbar = 33.61
# 		Decision=120, vhat 29.48 and new vbar for current state 29.48
# 		 Theta 1.0  - Iteration 2 - Step 5 - Current State 120 - vbar = 22.83
# 		Decision=28, vhat 21.56 and new vbar for current state 21.56
# 		 Theta 1.0  - Iteration 2 - Step 6 - Current State 28 - vbar = 21.19
# 		Decision=91, vhat 20.84 and new vbar for current state 20.84
# 		 Theta 1.0  - Iteration 2 - Step 7 - Current State 91 - vbar = 15.61
# 		Decision=106, vhat 15.67 and new vbar for current state 15.67
# 		 Theta 1.0  - Iteration 2 - Step 8 - Current State 106 - vbar = 12.33
# 		Decision=107, vhat 13.43 and new vbar for current state 13.43
# 		 Theta 1.0  - Iteration 2 - Step 9 - Current State 107 - vbar = 12.10
# 		Decision=108, vhat 9.12 and new vbar for current state 9.12
# 		 Theta 1.0  - Iteration 2 - Step 10 - Current State 108 - vbar = 4.01
# 		Decision=109, vhat 4.13 and new vbar for current state 4.13
# Finishing Theta 1.0 and Iteration 2 with 10 steps. Total cost: 41.626212491688065
#
# 	Theta 1.0  - Iteration 3 - Stepsize 1.00 - InitState 1 - Vbar 49.69
# 		 Theta 1.0  - Iteration 3 - Step 1 - Current State 1 - vbar = 49.69
# 		Decision=51, vhat 48.99 and new vbar for current state 48.99
# 		 Theta 1.0  - Iteration 3 - Step 2 - Current State 51 - vbar = 44.42
# 		Decision=52, vhat 43.63 and new vbar for current state 43.63
# 		 Theta 1.0  - Iteration 3 - Step 3 - Current State 52 - vbar = 34.27
# 		Decision=53, vhat 30.63 and new vbar for current state 30.63
# 		 Theta 1.0  - Iteration 3 - Step 4 - Current State 53 - vbar = 29.48
# 		Decision=120, vhat 32.19 and new vbar for current state 32.19
# 		 Theta 1.0  - Iteration 3 - Step 5 - Current State 120 - vbar = 21.56
# 		Decision=28, vhat 23.56 and new vbar for current state 23.56
# 		 Theta 1.0  - Iteration 3 - Step 6 - Current State 28 - vbar = 20.84
# 		Decision=91, vhat 21.16 and new vbar for current state 21.16
# 		 Theta 1.0  - Iteration 3 - Step 7 - Current State 91 - vbar = 15.67
# 		Decision=106, vhat 17.01 and new vbar for current state 17.01
# 		 Theta 1.0  - Iteration 3 - Step 8 - Current State 106 - vbar = 13.43
# 		Decision=107, vhat 9.87 and new vbar for current state 9.87
# 		 Theta 1.0  - Iteration 3 - Step 9 - Current State 107 - vbar = 9.12
# 		Decision=108, vhat 10.01 and new vbar for current state 10.01
# 		 Theta 1.0  - Iteration 3 - Step 10 - Current State 108 - vbar = 4.13
# 		Decision=109, vhat 7.10 and new vbar for current state 7.10
# Finishing Theta 1.0 and Iteration 3 with 10 steps. Total cost: 51.24654587998124
#
# 	Theta 1.0  - Iteration 4 - Stepsize 1.00 - InitState 1 - Vbar 48.99
# 		 Theta 1.0  - Iteration 4 - Step 1 - Current State 1 - vbar = 48.99
# 		Decision=51, vhat 48.21 and new vbar for current state 48.21
# 		 Theta 1.0  - Iteration 4 - Step 2 - Current State 51 - vbar = 43.63
# 		Decision=52, vhat 40.61 and new vbar for current state 40.61
# 		 Theta 1.0  - Iteration 4 - Step 3 - Current State 52 - vbar = 30.63
# 		Decision=53, vhat 33.10 and new vbar for current state 33.10
# 		 Theta 1.0  - Iteration 4 - Step 4 - Current State 53 - vbar = 32.19
# 		Decision=120, vhat 34.85 and new vbar for current state 34.85
# 		 Theta 1.0  - Iteration 4 - Step 5 - Current State 120 - vbar = 23.56
# 		Decision=28, vhat 22.53 and new vbar for current state 22.53
# 		 Theta 1.0  - Iteration 4 - Step 6 - Current State 28 - vbar = 21.16
# 		Decision=91, vhat 22.29 and new vbar for current state 22.29
# 		 Theta 1.0  - Iteration 4 - Step 7 - Current State 91 - vbar = 17.01
# 		Decision=106, vhat 13.50 and new vbar for current state 13.50
# 		 Theta 1.0  - Iteration 4 - Step 8 - Current State 106 - vbar = 9.87
# 		Decision=107, vhat 10.71 and new vbar for current state 10.71
# 		 Theta 1.0  - Iteration 4 - Step 9 - Current State 107 - vbar = 10.01
# 		Decision=108, vhat 13.33 and new vbar for current state 13.33
# 		 Theta 1.0  - Iteration 4 - Step 10 - Current State 108 - vbar = 7.10
# 		Decision=109, vhat 6.24 and new vbar for current state 6.24
# Finishing Theta 1.0 and Iteration 4 with 10 steps. Total cost: 50.20510896216623
#
# 	Theta 1.0  - Iteration 5 - Stepsize 1.00 - InitState 1 - Vbar 48.21
# 		 Theta 1.0  - Iteration 5 - Step 1 - Current State 1 - vbar = 48.21
# 		Decision=51, vhat 45.19 and new vbar for current state 45.19
# 		 Theta 1.0  - Iteration 5 - Step 2 - Current State 51 - vbar = 40.61
# 		Decision=52, vhat 43.55 and new vbar for current state 43.55
# 		 Theta 1.0  - Iteration 5 - Step 3 - Current State 52 - vbar = 33.10
# 		Decision=53, vhat 35.92 and new vbar for current state 35.92
# 		 Theta 1.0  - Iteration 5 - Step 4 - Current State 53 - vbar = 34.85
# 		Decision=120, vhat 31.56 and new vbar for current state 31.56
# 		 Theta 1.0  - Iteration 5 - Step 5 - Current State 120 - vbar = 22.53
# 		Decision=28, vhat 25.16 and new vbar for current state 25.16
# 		 Theta 1.0  - Iteration 5 - Step 6 - Current State 28 - vbar = 22.29
# 		Decision=91, vhat 18.83 and new vbar for current state 18.83
# 		 Theta 1.0  - Iteration 5 - Step 7 - Current State 91 - vbar = 13.50
# 		Decision=106, vhat 13.97 and new vbar for current state 13.97
# 		 Theta 1.0  - Iteration 5 - Step 8 - Current State 106 - vbar = 10.71
# 		Decision=107, vhat 14.33 and new vbar for current state 14.33
# 		 Theta 1.0  - Iteration 5 - Step 9 - Current State 107 - vbar = 13.33
# 		Decision=108, vhat 12.12 and new vbar for current state 12.12
# 		 Theta 1.0  - Iteration 5 - Step 10 - Current State 108 - vbar = 6.24
# 		Decision=109, vhat 4.67 and new vbar for current state 4.67
# Finishing Theta 1.0 and Iteration 5 with 10 steps. Total cost: 48.1246545406011
#
# 	Theta 1.0  - Iteration 6 - Stepsize 1.00 - InitState 1 - Vbar 45.19
# 		 Theta 1.0  - Iteration 6 - Step 1 - Current State 1 - vbar = 45.19
# 		Decision=51, vhat 48.13 and new vbar for current state 48.13
# 		 Theta 1.0  - Iteration 6 - Step 2 - Current State 51 - vbar = 43.55
# 		Decision=52, vhat 45.52 and new vbar for current state 45.52
# 		 Theta 1.0  - Iteration 6 - Step 3 - Current State 52 - vbar = 35.92
# 		Decision=53, vhat 32.62 and new vbar for current state 32.62
# 		 Theta 1.0  - Iteration 6 - Step 4 - Current State 53 - vbar = 31.56
# 		Decision=120, vhat 32.61 and new vbar for current state 32.61
# 		 Theta 1.0  - Iteration 6 - Step 5 - Current State 120 - vbar = 25.16
# 		Decision=28, vhat 19.70 and new vbar for current state 19.70
# 		 Theta 1.0  - Iteration 6 - Step 6 - Current State 28 - vbar = 18.83
# 		Decision=91, vhat 18.96 and new vbar for current state 18.96
# 		 Theta 1.0  - Iteration 6 - Step 7 - Current State 91 - vbar = 13.97
# 		Decision=106, vhat 17.74 and new vbar for current state 17.74
# 		 Theta 1.0  - Iteration 6 - Step 8 - Current State 106 - vbar = 14.33
# 		Decision=107, vhat 13.28 and new vbar for current state 13.28
# 		 Theta 1.0  - Iteration 6 - Step 9 - Current State 107 - vbar = 12.12
# 		Decision=108, vhat 9.80 and new vbar for current state 9.80
# 		 Theta 1.0  - Iteration 6 - Step 10 - Current State 108 - vbar = 4.67
# 		Decision=109, vhat 3.50 and new vbar for current state 3.50
# Finishing Theta 1.0 and Iteration 6 with 10 steps. Total cost: 41.76243924906786
#
# 	Theta 1.0  - Iteration 7 - Stepsize 1.00 - InitState 1 - Vbar 48.13
# 		 Theta 1.0  - Iteration 7 - Step 1 - Current State 1 - vbar = 48.13
# 		Decision=51, vhat 50.10 and new vbar for current state 50.10
# 		 Theta 1.0  - Iteration 7 - Step 2 - Current State 51 - vbar = 45.52
# 		Decision=52, vhat 40.21 and new vbar for current state 40.21
# 		 Theta 1.0  - Iteration 7 - Step 3 - Current State 52 - vbar = 32.62
# 		Decision=53, vhat 34.72 and new vbar for current state 34.72
# 		 Theta 1.0  - Iteration 7 - Step 4 - Current State 53 - vbar = 32.61
# 		Decision=120, vhat 30.05 and new vbar for current state 30.05
# 		 Theta 1.0  - Iteration 7 - Step 5 - Current State 120 - vbar = 19.70
# 		Decision=28, vhat 23.54 and new vbar for current state 23.54
# 		 Theta 1.0  - Iteration 7 - Step 6 - Current State 28 - vbar = 18.96
# 		Decision=91, vhat 22.92 and new vbar for current state 22.92
# 		 Theta 1.0  - Iteration 7 - Step 7 - Current State 91 - vbar = 17.74
# 		Decision=106, vhat 16.07 and new vbar for current state 16.07
# 		 Theta 1.0  - Iteration 7 - Step 8 - Current State 106 - vbar = 13.28
# 		Decision=107, vhat 10.73 and new vbar for current state 10.73
# 		 Theta 1.0  - Iteration 7 - Step 9 - Current State 107 - vbar = 9.80
# 		Decision=108, vhat 9.02 and new vbar for current state 9.02
# 		 Theta 1.0  - Iteration 7 - Step 10 - Current State 108 - vbar = 3.50
# 		Decision=109, vhat 4.23 and new vbar for current state 4.23
# Finishing Theta 1.0 and Iteration 7 with 10 steps. Total cost: 47.864486050940585
#
# 	Theta 1.0  - Iteration 8 - Stepsize 1.00 - InitState 1 - Vbar 50.10
# 		 Theta 1.0  - Iteration 8 - Step 1 - Current State 1 - vbar = 50.10
# 		Decision=51, vhat 44.79 and new vbar for current state 44.79
# 		 Theta 1.0  - Iteration 8 - Step 2 - Current State 51 - vbar = 40.21
# 		Decision=52, vhat 45.05 and new vbar for current state 45.05
# 		 Theta 1.0  - Iteration 8 - Step 3 - Current State 52 - vbar = 34.72
# 		Decision=53, vhat 30.98 and new vbar for current state 30.98
# 		 Theta 1.0  - Iteration 8 - Step 4 - Current State 53 - vbar = 30.05
# 		Decision=120, vhat 32.71 and new vbar for current state 32.71
# 		 Theta 1.0  - Iteration 8 - Step 5 - Current State 120 - vbar = 23.54
# 		Decision=28, vhat 26.89 and new vbar for current state 26.89
# 		 Theta 1.0  - Iteration 8 - Step 6 - Current State 28 - vbar = 22.92
# 		Decision=91, vhat 21.65 and new vbar for current state 21.65
# 		 Theta 1.0  - Iteration 8 - Step 7 - Current State 91 - vbar = 16.07
# 		Decision=106, vhat 13.57 and new vbar for current state 13.57
# 		 Theta 1.0  - Iteration 8 - Step 8 - Current State 106 - vbar = 10.73
# 		Decision=107, vhat 10.28 and new vbar for current state 10.28
# 		 Theta 1.0  - Iteration 8 - Step 9 - Current State 107 - vbar = 9.02
# 		Decision=108, vhat 9.38 and new vbar for current state 9.38
# 		 Theta 1.0  - Iteration 8 - Step 10 - Current State 108 - vbar = 4.23
# 		Decision=109, vhat 2.79 and new vbar for current state 2.79
# Finishing Theta 1.0 and Iteration 8 with 10 steps. Total cost: 46.59085439105585
#
# 	Theta 1.0  - Iteration 9 - Stepsize 1.00 - InitState 1 - Vbar 44.79
# 		 Theta 1.0  - Iteration 9 - Step 1 - Current State 1 - vbar = 44.79
# 		Decision=51, vhat 49.62 and new vbar for current state 49.62
# 		 Theta 1.0  - Iteration 9 - Step 2 - Current State 51 - vbar = 45.05
# 		Decision=52, vhat 42.55 and new vbar for current state 42.55
# 		 Theta 1.0  - Iteration 9 - Step 3 - Current State 52 - vbar = 30.98
# 		Decision=53, vhat 34.51 and new vbar for current state 34.51
# 		 Theta 1.0  - Iteration 9 - Step 4 - Current State 53 - vbar = 32.71
# 		Decision=120, vhat 34.62 and new vbar for current state 34.62
# 		 Theta 1.0  - Iteration 9 - Step 5 - Current State 120 - vbar = 26.89
# 		Decision=28, vhat 24.79 and new vbar for current state 24.79
# 		 Theta 1.0  - Iteration 9 - Step 6 - Current State 28 - vbar = 21.65
# 		Decision=91, vhat 18.67 and new vbar for current state 18.67
# 		 Theta 1.0  - Iteration 9 - Step 7 - Current State 91 - vbar = 13.57
# 		Decision=106, vhat 13.38 and new vbar for current state 13.38
# 		 Theta 1.0  - Iteration 9 - Step 8 - Current State 106 - vbar = 10.28
# 		Decision=107, vhat 10.39 and new vbar for current state 10.39
# 		 Theta 1.0  - Iteration 9 - Step 9 - Current State 107 - vbar = 9.38
# 		Decision=108, vhat 8.73 and new vbar for current state 8.73
# 		 Theta 1.0  - Iteration 9 - Step 10 - Current State 108 - vbar = 2.79
# 		Decision=109, vhat 7.98 and new vbar for current state 7.98
# Finishing Theta 1.0 and Iteration 9 with 10 steps. Total cost: 51.952690681090246
#
# 	Theta 1.0  - Iteration 10 - Stepsize 1.00 - InitState 1 - Vbar 49.62
# 		 Theta 1.0  - Iteration 10 - Step 1 - Current State 1 - vbar = 49.62
# 		Decision=51, vhat 47.13 and new vbar for current state 47.13
# 		 Theta 1.0  - Iteration 10 - Step 2 - Current State 51 - vbar = 42.55
# 		Decision=52, vhat 44.05 and new vbar for current state 44.05
# 		 Theta 1.0  - Iteration 10 - Step 3 - Current State 52 - vbar = 34.51
# 		Decision=53, vhat 35.73 and new vbar for current state 35.73
# 		 Theta 1.0  - Iteration 10 - Step 4 - Current State 53 - vbar = 34.62
# 		Decision=120, vhat 34.01 and new vbar for current state 34.01
# 		 Theta 1.0  - Iteration 10 - Step 5 - Current State 120 - vbar = 24.79
# 		Decision=28, vhat 23.01 and new vbar for current state 23.01
# 		 Theta 1.0  - Iteration 10 - Step 6 - Current State 28 - vbar = 18.67
# 		Decision=91, vhat 18.74 and new vbar for current state 18.74
# 		 Theta 1.0  - Iteration 10 - Step 7 - Current State 91 - vbar = 13.38
# 		Decision=106, vhat 14.17 and new vbar for current state 14.17
# 		 Theta 1.0  - Iteration 10 - Step 8 - Current State 106 - vbar = 10.39
# 		Decision=107, vhat 10.01 and new vbar for current state 10.01
# 		 Theta 1.0  - Iteration 10 - Step 9 - Current State 107 - vbar = 8.73
# 		Decision=108, vhat 13.14 and new vbar for current state 13.14
# 		 Theta 1.0  - Iteration 10 - Step 10 - Current State 108 - vbar = 7.98
# 		Decision=109, vhat 7.90 and new vbar for current state 7.90
# Finishing Theta 1.0 and Iteration 10 with 10 steps. Total cost: 52.25255731878868
#
# 	Theta 1.0  - Iteration 11 - Stepsize 1.00 - InitState 1 - Vbar 47.13
# 		 Theta 1.0  - Iteration 11 - Step 1 - Current State 1 - vbar = 47.13
# 		Decision=51, vhat 48.62 and new vbar for current state 48.62
# 		 Theta 1.0  - Iteration 11 - Step 2 - Current State 51 - vbar = 44.05
# 		Decision=52, vhat 45.38 and new vbar for current state 45.38
# 		 Theta 1.0  - Iteration 11 - Step 3 - Current State 52 - vbar = 35.73
# 		Decision=53, vhat 35.86 and new vbar for current state 35.86
# 		 Theta 1.0  - Iteration 11 - Step 4 - Current State 53 - vbar = 34.01
# 		Decision=120, vhat 34.10 and new vbar for current state 34.10
# 		 Theta 1.0  - Iteration 11 - Step 5 - Current State 120 - vbar = 23.01
# 		Decision=28, vhat 22.68 and new vbar for current state 22.68
# 		 Theta 1.0  - Iteration 11 - Step 6 - Current State 28 - vbar = 18.74
# 		Decision=91, vhat 19.17 and new vbar for current state 19.17
# 		 Theta 1.0  - Iteration 11 - Step 7 - Current State 91 - vbar = 14.17
# 		Decision=106, vhat 13.77 and new vbar for current state 13.77
# 		 Theta 1.0  - Iteration 11 - Step 8 - Current State 106 - vbar = 10.01
# 		Decision=107, vhat 14.25 and new vbar for current state 14.25
# 		 Theta 1.0  - Iteration 11 - Step 9 - Current State 107 - vbar = 13.14
# 		Decision=108, vhat 12.89 and new vbar for current state 12.89
# 		 Theta 1.0  - Iteration 11 - Step 10 - Current State 108 - vbar = 7.90
# 		Decision=109, vhat 7.19 and new vbar for current state 7.19
# Finishing Theta 1.0 and Iteration 11 with 10 steps. Total cost: 53.16180697251598
#
# 	Theta 1.0  - Iteration 12 - Stepsize 1.00 - InitState 1 - Vbar 48.62
# 		 Theta 1.0  - Iteration 12 - Step 1 - Current State 1 - vbar = 48.62
# 		Decision=51, vhat 49.96 and new vbar for current state 49.96
# 		 Theta 1.0  - Iteration 12 - Step 2 - Current State 51 - vbar = 45.38
# 		Decision=52, vhat 45.40 and new vbar for current state 45.40
# 		 Theta 1.0  - Iteration 12 - Step 3 - Current State 52 - vbar = 35.86
# 		Decision=53, vhat 35.56 and new vbar for current state 35.56
# 		 Theta 1.0  - Iteration 12 - Step 4 - Current State 53 - vbar = 34.10
# 		Decision=120, vhat 32.87 and new vbar for current state 32.87
# 		 Theta 1.0  - Iteration 12 - Step 5 - Current State 120 - vbar = 22.68
# 		Decision=28, vhat 19.53 and new vbar for current state 19.53
# 		 Theta 1.0  - Iteration 12 - Step 6 - Current State 28 - vbar = 19.17
# 		Decision=91, vhat 18.81 and new vbar for current state 18.81
# 		 Theta 1.0  - Iteration 12 - Step 7 - Current State 91 - vbar = 13.77
# 		Decision=106, vhat 17.92 and new vbar for current state 17.92
# 		 Theta 1.0  - Iteration 12 - Step 8 - Current State 106 - vbar = 14.25
# 		Decision=107, vhat 13.83 and new vbar for current state 13.83
# 		 Theta 1.0  - Iteration 12 - Step 9 - Current State 107 - vbar = 12.89
# 		Decision=108, vhat 12.84 and new vbar for current state 12.84
# 		 Theta 1.0  - Iteration 12 - Step 10 - Current State 108 - vbar = 7.19
# 		Decision=109, vhat 3.39 and new vbar for current state 3.39
# Finishing Theta 1.0 and Iteration 12 with 10 steps. Total cost: 44.82460855592633
#
# 	Theta 1.0  - Iteration 13 - Stepsize 1.00 - InitState 1 - Vbar 49.96
# 		 Theta 1.0  - Iteration 13 - Step 1 - Current State 1 - vbar = 49.96
# 		Decision=51, vhat 49.98 and new vbar for current state 49.98
# 		 Theta 1.0  - Iteration 13 - Step 2 - Current State 51 - vbar = 45.40
# 		Decision=52, vhat 45.64 and new vbar for current state 45.64
# 		 Theta 1.0  - Iteration 13 - Step 3 - Current State 52 - vbar = 35.56
# 		Decision=53, vhat 34.47 and new vbar for current state 34.47
# 		 Theta 1.0  - Iteration 13 - Step 4 - Current State 53 - vbar = 32.87
# 		Decision=120, vhat 27.66 and new vbar for current state 27.66
# 		 Theta 1.0  - Iteration 13 - Step 5 - Current State 120 - vbar = 19.53
# 		Decision=28, vhat 19.01 and new vbar for current state 19.01
# 		 Theta 1.0  - Iteration 13 - Step 6 - Current State 28 - vbar = 18.81
# 		Decision=91, vhat 23.38 and new vbar for current state 23.38
# 		 Theta 1.0  - Iteration 13 - Step 7 - Current State 91 - vbar = 17.92
# 		Decision=106, vhat 17.43 and new vbar for current state 17.43
# 		 Theta 1.0  - Iteration 13 - Step 8 - Current State 106 - vbar = 13.83
# 		Decision=107, vhat 13.85 and new vbar for current state 13.85
# 		 Theta 1.0  - Iteration 13 - Step 9 - Current State 107 - vbar = 12.84
# 		Decision=108, vhat 8.38 and new vbar for current state 8.38
# 		 Theta 1.0  - Iteration 13 - Step 10 - Current State 108 - vbar = 3.39
# 		Decision=109, vhat 3.44 and new vbar for current state 3.44
# Finishing Theta 1.0 and Iteration 13 with 10 steps. Total cost: 43.08001768712015
#
# 	Theta 1.0  - Iteration 14 - Stepsize 1.00 - InitState 1 - Vbar 49.98
# 		 Theta 1.0  - Iteration 14 - Step 1 - Current State 1 - vbar = 49.98
# 		Decision=51, vhat 50.22 and new vbar for current state 50.22
# 		 Theta 1.0  - Iteration 14 - Step 2 - Current State 51 - vbar = 45.64
# 		Decision=52, vhat 43.23 and new vbar for current state 43.23
# 		 Theta 1.0  - Iteration 14 - Step 3 - Current State 52 - vbar = 34.47
# 		Decision=53, vhat 29.93 and new vbar for current state 29.93
# 		 Theta 1.0  - Iteration 14 - Step 4 - Current State 53 - vbar = 27.66
# 		Decision=120, vhat 30.41 and new vbar for current state 30.41
# 		 Theta 1.0  - Iteration 14 - Step 5 - Current State 120 - vbar = 19.01
# 		Decision=28, vhat 24.95 and new vbar for current state 24.95
# 		 Theta 1.0  - Iteration 14 - Step 6 - Current State 28 - vbar = 23.38
# 		Decision=91, vhat 22.58 and new vbar for current state 22.58
# 		 Theta 1.0  - Iteration 14 - Step 7 - Current State 91 - vbar = 17.43
# 		Decision=106, vhat 17.16 and new vbar for current state 17.16
# 		 Theta 1.0  - Iteration 14 - Step 8 - Current State 106 - vbar = 13.85
# 		Decision=107, vhat 9.10 and new vbar for current state 9.10
# 		 Theta 1.0  - Iteration 14 - Step 9 - Current State 107 - vbar = 8.38
# 		Decision=108, vhat 9.72 and new vbar for current state 9.72
# 		 Theta 1.0  - Iteration 14 - Step 10 - Current State 108 - vbar = 3.44
# 		Decision=109, vhat 7.11 and new vbar for current state 7.11
# Finishing Theta 1.0 and Iteration 14 with 10 steps. Total cost: 51.15925519389259
#
# 	Theta 1.0  - Iteration 15 - Stepsize 1.00 - InitState 1 - Vbar 50.22
# 		 Theta 1.0  - Iteration 15 - Step 1 - Current State 1 - vbar = 50.22
# 		Decision=51, vhat 47.81 and new vbar for current state 47.81
# 		 Theta 1.0  - Iteration 15 - Step 2 - Current State 51 - vbar = 43.23
# 		Decision=52, vhat 41.24 and new vbar for current state 41.24
# 		 Theta 1.0  - Iteration 15 - Step 3 - Current State 52 - vbar = 29.93
# 		Decision=53, vhat 32.19 and new vbar for current state 32.19
# 		 Theta 1.0  - Iteration 15 - Step 4 - Current State 53 - vbar = 30.41
# 		Decision=120, vhat 36.21 and new vbar for current state 36.21
# 		 Theta 1.0  - Iteration 15 - Step 5 - Current State 120 - vbar = 24.95
# 		Decision=28, vhat 23.66 and new vbar for current state 23.66
# 		 Theta 1.0  - Iteration 15 - Step 6 - Current State 28 - vbar = 22.58
# 		Decision=91, vhat 22.15 and new vbar for current state 22.15
# 		 Theta 1.0  - Iteration 15 - Step 7 - Current State 91 - vbar = 17.16
# 		Decision=106, vhat 12.03 and new vbar for current state 12.03
# 		 Theta 1.0  - Iteration 15 - Step 8 - Current State 106 - vbar = 9.10
# 		Decision=107, vhat 10.62 and new vbar for current state 10.62
# 		 Theta 1.0  - Iteration 15 - Step 9 - Current State 107 - vbar = 9.72
# 		Decision=108, vhat 13.21 and new vbar for current state 13.21
# 		 Theta 1.0  - Iteration 15 - Step 10 - Current State 108 - vbar = 7.11
# 		Decision=109, vhat 6.48 and new vbar for current state 6.48
# Finishing Theta 1.0 and Iteration 15 with 10 steps. Total cost: 51.38369044468814
#
# 	Theta 1.0  - Iteration 16 - Stepsize 1.00 - InitState 1 - Vbar 47.81
# 		 Theta 1.0  - Iteration 16 - Step 1 - Current State 1 - vbar = 47.81
# 		Decision=51, vhat 45.82 and new vbar for current state 45.82
# 		 Theta 1.0  - Iteration 16 - Step 2 - Current State 51 - vbar = 41.24
# 		Decision=52, vhat 41.81 and new vbar for current state 41.81
# 		 Theta 1.0  - Iteration 16 - Step 3 - Current State 52 - vbar = 32.19
# 		Decision=53, vhat 37.25 and new vbar for current state 37.25
# 		 Theta 1.0  - Iteration 16 - Step 4 - Current State 53 - vbar = 36.21
# 		Decision=120, vhat 33.92 and new vbar for current state 33.92
# 		 Theta 1.0  - Iteration 16 - Step 5 - Current State 120 - vbar = 23.66
# 		Decision=28, vhat 25.77 and new vbar for current state 25.77
# 		 Theta 1.0  - Iteration 16 - Step 6 - Current State 28 - vbar = 22.15
# 		Decision=91, vhat 17.56 and new vbar for current state 17.56
# 		 Theta 1.0  - Iteration 16 - Step 7 - Current State 91 - vbar = 12.03
# 		Decision=106, vhat 14.06 and new vbar for current state 14.06
# 		 Theta 1.0  - Iteration 16 - Step 8 - Current State 106 - vbar = 10.62
# 		Decision=107, vhat 14.55 and new vbar for current state 14.55
# 		 Theta 1.0  - Iteration 16 - Step 9 - Current State 107 - vbar = 13.21
# 		Decision=108, vhat 11.60 and new vbar for current state 11.60
# 		 Theta 1.0  - Iteration 16 - Step 10 - Current State 108 - vbar = 6.48
# 		Decision=109, vhat 6.64 and new vbar for current state 6.64
# Finishing Theta 1.0 and Iteration 16 with 10 steps. Total cost: 51.20662167301165
#
# 	Theta 1.0  - Iteration 17 - Stepsize 1.00 - InitState 1 - Vbar 45.82
# 		 Theta 1.0  - Iteration 17 - Step 1 - Current State 1 - vbar = 45.82
# 		Decision=51, vhat 46.39 and new vbar for current state 46.39
# 		 Theta 1.0  - Iteration 17 - Step 2 - Current State 51 - vbar = 41.81
# 		Decision=52, vhat 46.27 and new vbar for current state 46.27
# 		 Theta 1.0  - Iteration 17 - Step 3 - Current State 52 - vbar = 37.25
# 		Decision=53, vhat 34.73 and new vbar for current state 34.73
# 		 Theta 1.0  - Iteration 17 - Step 4 - Current State 53 - vbar = 33.92
# 		Decision=120, vhat 35.95 and new vbar for current state 35.95
# 		 Theta 1.0  - Iteration 17 - Step 5 - Current State 120 - vbar = 25.77
# 		Decision=28, vhat 20.99 and new vbar for current state 20.99
# 		 Theta 1.0  - Iteration 17 - Step 6 - Current State 28 - vbar = 17.56
# 		Decision=91, vhat 19.57 and new vbar for current state 19.57
# 		 Theta 1.0  - Iteration 17 - Step 7 - Current State 91 - vbar = 14.06
# 		Decision=106, vhat 17.86 and new vbar for current state 17.86
# 		 Theta 1.0  - Iteration 17 - Step 8 - Current State 106 - vbar = 14.55
# 		Decision=107, vhat 12.55 and new vbar for current state 12.55
# 		 Theta 1.0  - Iteration 17 - Step 9 - Current State 107 - vbar = 11.60
# 		Decision=108, vhat 12.96 and new vbar for current state 12.96
# 		 Theta 1.0  - Iteration 17 - Step 10 - Current State 108 - vbar = 6.64
# 		Decision=109, vhat 5.53 and new vbar for current state 5.53
# Finishing Theta 1.0 and Iteration 17 with 10 steps. Total cost: 49.64917216431523
#
# 	Theta 1.0  - Iteration 18 - Stepsize 1.00 - InitState 1 - Vbar 46.39
# 		 Theta 1.0  - Iteration 18 - Step 1 - Current State 1 - vbar = 46.39
# 		Decision=51, vhat 50.85 and new vbar for current state 50.85
# 		 Theta 1.0  - Iteration 18 - Step 2 - Current State 51 - vbar = 46.27
# 		Decision=52, vhat 43.62 and new vbar for current state 43.62
# 		 Theta 1.0  - Iteration 18 - Step 3 - Current State 52 - vbar = 34.73
# 		Decision=53, vhat 37.46 and new vbar for current state 37.46
# 		 Theta 1.0  - Iteration 18 - Step 4 - Current State 53 - vbar = 35.95
# 		Decision=120, vhat 31.33 and new vbar for current state 31.33
# 		 Theta 1.0  - Iteration 18 - Step 5 - Current State 120 - vbar = 20.99
# 		Decision=28, vhat 20.85 and new vbar for current state 20.85
# 		 Theta 1.0  - Iteration 18 - Step 6 - Current State 28 - vbar = 19.57
# 		Decision=91, vhat 23.25 and new vbar for current state 23.25
# 		 Theta 1.0  - Iteration 18 - Step 7 - Current State 91 - vbar = 17.86
# 		Decision=106, vhat 16.07 and new vbar for current state 16.07
# 		 Theta 1.0  - Iteration 18 - Step 8 - Current State 106 - vbar = 12.55
# 		Decision=107, vhat 14.05 and new vbar for current state 14.05
# 		 Theta 1.0  - Iteration 18 - Step 9 - Current State 107 - vbar = 12.96
# 		Decision=108, vhat 11.95 and new vbar for current state 11.95
# 		 Theta 1.0  - Iteration 18 - Step 10 - Current State 108 - vbar = 5.53
# 		Decision=109, vhat 3.14 and new vbar for current state 3.14
# Finishing Theta 1.0 and Iteration 18 with 10 steps. Total cost: 46.160852273448285
#
# 	Theta 1.0  - Iteration 19 - Stepsize 1.00 - InitState 1 - Vbar 50.85
# 		 Theta 1.0  - Iteration 19 - Step 1 - Current State 1 - vbar = 50.85
# 		Decision=51, vhat 48.20 and new vbar for current state 48.20
# 		 Theta 1.0  - Iteration 19 - Step 2 - Current State 51 - vbar = 43.62
# 		Decision=52, vhat 45.63 and new vbar for current state 45.63
# 		 Theta 1.0  - Iteration 19 - Step 3 - Current State 52 - vbar = 37.46
# 		Decision=53, vhat 32.03 and new vbar for current state 32.03
# 		 Theta 1.0  - Iteration 19 - Step 4 - Current State 53 - vbar = 31.33
# 		Decision=120, vhat 27.86 and new vbar for current state 27.86
# 		 Theta 1.0  - Iteration 19 - Step 5 - Current State 120 - vbar = 20.85
# 		Decision=28, vhat 25.58 and new vbar for current state 25.58
# 		 Theta 1.0  - Iteration 19 - Step 6 - Current State 28 - vbar = 23.25
# 		Decision=91, vhat 21.37 and new vbar for current state 21.37
# 		 Theta 1.0  - Iteration 19 - Step 7 - Current State 91 - vbar = 16.07
# 		Decision=106, vhat 17.35 and new vbar for current state 17.35
# 		 Theta 1.0  - Iteration 19 - Step 8 - Current State 106 - vbar = 14.05
# 		Decision=107, vhat 13.17 and new vbar for current state 13.17
# 		 Theta 1.0  - Iteration 19 - Step 9 - Current State 107 - vbar = 11.95
# 		Decision=108, vhat 9.08 and new vbar for current state 9.08
# 		 Theta 1.0  - Iteration 19 - Step 10 - Current State 108 - vbar = 3.14
# 		Decision=109, vhat 6.39 and new vbar for current state 6.39
# Finishing Theta 1.0 and Iteration 19 with 10 steps. Total cost: 44.910053311063784
#
# 	Theta 1.0  - Iteration 20 - Stepsize 1.00 - InitState 1 - Vbar 48.20
# 		 Theta 1.0  - Iteration 20 - Step 1 - Current State 1 - vbar = 48.20
# 		Decision=51, vhat 50.20 and new vbar for current state 50.20
# 		 Theta 1.0  - Iteration 20 - Step 2 - Current State 51 - vbar = 45.63
# 		Decision=52, vhat 43.26 and new vbar for current state 43.26
# 		 Theta 1.0  - Iteration 20 - Step 3 - Current State 52 - vbar = 32.03
# 		Decision=53, vhat 28.79 and new vbar for current state 28.79
# 		 Theta 1.0  - Iteration 20 - Step 4 - Current State 53 - vbar = 27.86
# 		Decision=120, vhat 36.54 and new vbar for current state 36.54
# 		 Theta 1.0  - Iteration 20 - Step 5 - Current State 120 - vbar = 25.58
# 		Decision=28, vhat 24.07 and new vbar for current state 24.07
# 		 Theta 1.0  - Iteration 20 - Step 6 - Current State 28 - vbar = 21.37
# 		Decision=91, vhat 22.80 and new vbar for current state 22.80
# 		 Theta 1.0  - Iteration 20 - Step 7 - Current State 91 - vbar = 17.35
# 		Decision=106, vhat 15.94 and new vbar for current state 15.94
# 		 Theta 1.0  - Iteration 20 - Step 8 - Current State 106 - vbar = 13.17
# 		Decision=107, vhat 9.97 and new vbar for current state 9.97
# 		 Theta 1.0  - Iteration 20 - Step 9 - Current State 107 - vbar = 9.08
# 		Decision=108, vhat 11.40 and new vbar for current state 11.40
# 		 Theta 1.0  - Iteration 20 - Step 10 - Current State 108 - vbar = 6.39
# 		Decision=109, vhat 7.08 and new vbar for current state 7.08
# Finishing Theta 1.0 and Iteration 20 with 10 steps. Total cost: 51.611027704037134
#
# 	Theta 1.0  - Iteration 21 - Stepsize 1.00 - InitState 1 - Vbar 50.20
# 		 Theta 1.0  - Iteration 21 - Step 1 - Current State 1 - vbar = 50.20
# 		Decision=51, vhat 47.84 and new vbar for current state 47.84
# 		 Theta 1.0  - Iteration 21 - Step 2 - Current State 51 - vbar = 43.26
# 		Decision=52, vhat 36.82 and new vbar for current state 36.82
# 		 Theta 1.0  - Iteration 21 - Step 3 - Current State 52 - vbar = 28.79
# 		Decision=53, vhat 37.36 and new vbar for current state 37.36
# 		 Theta 1.0  - Iteration 21 - Step 4 - Current State 53 - vbar = 36.54
# 		Decision=120, vhat 35.57 and new vbar for current state 35.57
# 		 Theta 1.0  - Iteration 21 - Step 5 - Current State 120 - vbar = 24.07
# 		Decision=28, vhat 26.68 and new vbar for current state 26.68
# 		 Theta 1.0  - Iteration 21 - Step 6 - Current State 28 - vbar = 22.80
# 		Decision=91, vhat 20.93 and new vbar for current state 20.93
# 		 Theta 1.0  - Iteration 21 - Step 7 - Current State 91 - vbar = 15.94
# 		Decision=106, vhat 13.52 and new vbar for current state 13.52
# 		 Theta 1.0  - Iteration 21 - Step 8 - Current State 106 - vbar = 9.97
# 		Decision=107, vhat 12.64 and new vbar for current state 12.64
# 		 Theta 1.0  - Iteration 21 - Step 9 - Current State 107 - vbar = 11.40
# 		Decision=108, vhat 13.32 and new vbar for current state 13.32
# 		 Theta 1.0  - Iteration 21 - Step 10 - Current State 108 - vbar = 7.08
# 		Decision=109, vhat 2.63 and new vbar for current state 2.63
# Finishing Theta 1.0 and Iteration 21 with 10 steps. Total cost: 47.46417746841364
#
# 	Theta 1.0  - Iteration 22 - Stepsize 1.00 - InitState 1 - Vbar 47.84
# 		 Theta 1.0  - Iteration 22 - Step 1 - Current State 1 - vbar = 47.84
# 		Decision=51, vhat 41.39 and new vbar for current state 41.39
# 		 Theta 1.0  - Iteration 22 - Step 2 - Current State 51 - vbar = 36.82
# 		Decision=52, vhat 48.14 and new vbar for current state 48.14
# 		 Theta 1.0  - Iteration 22 - Step 3 - Current State 52 - vbar = 37.36
# 		Decision=53, vhat 36.84 and new vbar for current state 36.84
# 		 Theta 1.0  - Iteration 22 - Step 4 - Current State 53 - vbar = 35.57
# 		Decision=120, vhat 36.95 and new vbar for current state 36.95
# 		 Theta 1.0  - Iteration 22 - Step 5 - Current State 120 - vbar = 26.68
# 		Decision=28, vhat 22.56 and new vbar for current state 22.56
# 		 Theta 1.0  - Iteration 22 - Step 6 - Current State 28 - vbar = 20.93
# 		Decision=91, vhat 18.47 and new vbar for current state 18.47
# 		 Theta 1.0  - Iteration 22 - Step 7 - Current State 91 - vbar = 13.52
# 		Decision=106, vhat 16.33 and new vbar for current state 16.33
# 		 Theta 1.0  - Iteration 22 - Step 8 - Current State 106 - vbar = 12.64
# 		Decision=107, vhat 14.67 and new vbar for current state 14.67
# 		 Theta 1.0  - Iteration 22 - Step 9 - Current State 107 - vbar = 13.32
# 		Decision=108, vhat 8.44 and new vbar for current state 8.44
# 		 Theta 1.0  - Iteration 22 - Step 10 - Current State 108 - vbar = 2.63
# 		Decision=109, vhat 5.46 and new vbar for current state 5.46
# Finishing Theta 1.0 and Iteration 22 with 10 steps. Total cost: 49.78979258402411
#
# 	Theta 1.0  - Iteration 23 - Stepsize 1.00 - InitState 1 - Vbar 41.39
# 		 Theta 1.0  - Iteration 23 - Step 1 - Current State 1 - vbar = 41.39
# 		Decision=51, vhat 52.72 and new vbar for current state 52.72
# 		 Theta 1.0  - Iteration 23 - Step 2 - Current State 51 - vbar = 48.14
# 		Decision=52, vhat 48.21 and new vbar for current state 48.21
# 		 Theta 1.0  - Iteration 23 - Step 3 - Current State 52 - vbar = 36.84
# 		Decision=53, vhat 37.66 and new vbar for current state 37.66
# 		 Theta 1.0  - Iteration 23 - Step 4 - Current State 53 - vbar = 36.95
# 		Decision=120, vhat 30.19 and new vbar for current state 30.19
# 		 Theta 1.0  - Iteration 23 - Step 5 - Current State 120 - vbar = 22.56
# 		Decision=28, vhat 22.38 and new vbar for current state 22.38
# 		 Theta 1.0  - Iteration 23 - Step 6 - Current State 28 - vbar = 18.47
# 		Decision=91, vhat 21.62 and new vbar for current state 21.62
# 		 Theta 1.0  - Iteration 23 - Step 7 - Current State 91 - vbar = 16.33
# 		Decision=106, vhat 18.25 and new vbar for current state 18.25
# 		 Theta 1.0  - Iteration 23 - Step 8 - Current State 106 - vbar = 14.67
# 		Decision=107, vhat 9.36 and new vbar for current state 9.36
# 		 Theta 1.0  - Iteration 23 - Step 9 - Current State 107 - vbar = 8.44
# 		Decision=108, vhat 11.81 and new vbar for current state 11.81
# 		 Theta 1.0  - Iteration 23 - Step 10 - Current State 108 - vbar = 5.46
# 		Decision=109, vhat 2.65 and new vbar for current state 2.65
# Finishing Theta 1.0 and Iteration 23 with 10 steps. Total cost: 46.98441424481841
#
# 	Theta 1.0  - Iteration 24 - Stepsize 1.00 - InitState 1 - Vbar 52.72
# 		 Theta 1.0  - Iteration 24 - Step 1 - Current State 1 - vbar = 52.72
# 		Decision=51, vhat 52.79 and new vbar for current state 52.79
# 		 Theta 1.0  - Iteration 24 - Step 2 - Current State 51 - vbar = 48.21
# 		Decision=52, vhat 48.95 and new vbar for current state 48.95
# 		 Theta 1.0  - Iteration 24 - Step 3 - Current State 52 - vbar = 37.66
# 		Decision=53, vhat 31.34 and new vbar for current state 31.34
# 		 Theta 1.0  - Iteration 24 - Step 4 - Current State 53 - vbar = 30.19
# 		Decision=120, vhat 32.62 and new vbar for current state 32.62
# 		 Theta 1.0  - Iteration 24 - Step 5 - Current State 120 - vbar = 22.38
# 		Decision=28, vhat 26.40 and new vbar for current state 26.40
# 		 Theta 1.0  - Iteration 24 - Step 6 - Current State 28 - vbar = 21.62
# 		Decision=91, vhat 23.53 and new vbar for current state 23.53
# 		 Theta 1.0  - Iteration 24 - Step 7 - Current State 91 - vbar = 18.25
# 		Decision=106, vhat 12.56 and new vbar for current state 12.56
# 		 Theta 1.0  - Iteration 24 - Step 8 - Current State 106 - vbar = 9.36
# 		Decision=107, vhat 12.54 and new vbar for current state 12.54
# 		 Theta 1.0  - Iteration 24 - Step 9 - Current State 107 - vbar = 11.81
# 		Decision=108, vhat 7.91 and new vbar for current state 7.91
# 		 Theta 1.0  - Iteration 24 - Step 10 - Current State 108 - vbar = 2.65
# 		Decision=109, vhat 8.63 and new vbar for current state 8.63
# Finishing Theta 1.0 and Iteration 24 with 10 steps. Total cost: 55.14609615379702
#
# 	Theta 1.0  - Iteration 25 - Stepsize 1.00 - InitState 1 - Vbar 52.79
# 		 Theta 1.0  - Iteration 25 - Step 1 - Current State 1 - vbar = 52.79
# 		Decision=51, vhat 53.53 and new vbar for current state 53.53
# 		 Theta 1.0  - Iteration 25 - Step 2 - Current State 51 - vbar = 48.95
# 		Decision=52, vhat 42.83 and new vbar for current state 42.83
# 		 Theta 1.0  - Iteration 25 - Step 3 - Current State 52 - vbar = 31.34
# 		Decision=53, vhat 34.74 and new vbar for current state 34.74
# 		 Theta 1.0  - Iteration 25 - Step 4 - Current State 53 - vbar = 32.62
# 		Decision=120, vhat 34.20 and new vbar for current state 34.20
# 		 Theta 1.0  - Iteration 25 - Step 5 - Current State 120 - vbar = 26.40
# 		Decision=28, vhat 27.19 and new vbar for current state 27.19
# 		 Theta 1.0  - Iteration 25 - Step 6 - Current State 28 - vbar = 23.53
# 		Decision=91, vhat 17.58 and new vbar for current state 17.58
# 		 Theta 1.0  - Iteration 25 - Step 7 - Current State 91 - vbar = 12.56
# 		Decision=106, vhat 15.65 and new vbar for current state 15.65
# 		 Theta 1.0  - Iteration 25 - Step 8 - Current State 106 - vbar = 12.54
# 		Decision=107, vhat 9.15 and new vbar for current state 9.15
# 		 Theta 1.0  - Iteration 25 - Step 9 - Current State 107 - vbar = 7.91
# 		Decision=108, vhat 14.89 and new vbar for current state 14.89
# 		 Theta 1.0  - Iteration 25 - Step 10 - Current State 108 - vbar = 8.63
# 		Decision=109, vhat 4.16 and new vbar for current state 4.16
# Finishing Theta 1.0 and Iteration 25 with 10 steps. Total cost: 49.42750551564462
#
# 	Theta 1.0  - Iteration 26 - Stepsize 1.00 - InitState 1 - Vbar 53.53
# 		 Theta 1.0  - Iteration 26 - Step 1 - Current State 1 - vbar = 53.53
# 		Decision=51, vhat 47.40 and new vbar for current state 47.40
# 		 Theta 1.0  - Iteration 26 - Step 2 - Current State 51 - vbar = 42.83
# 		Decision=52, vhat 45.54 and new vbar for current state 45.54
# 		 Theta 1.0  - Iteration 26 - Step 3 - Current State 52 - vbar = 34.74
# 		Decision=53, vhat 35.41 and new vbar for current state 35.41
# 		 Theta 1.0  - Iteration 26 - Step 4 - Current State 53 - vbar = 34.20
# 		Decision=120, vhat 33.83 and new vbar for current state 33.83
# 		 Theta 1.0  - Iteration 26 - Step 5 - Current State 120 - vbar = 27.19
# 		Decision=28, vhat 19.03 and new vbar for current state 19.03
# 		 Theta 1.0  - Iteration 26 - Step 6 - Current State 28 - vbar = 17.58
# 		Decision=91, vhat 20.58 and new vbar for current state 20.58
# 		 Theta 1.0  - Iteration 26 - Step 7 - Current State 91 - vbar = 15.65
# 		Decision=106, vhat 12.60 and new vbar for current state 12.60
# 		 Theta 1.0  - Iteration 26 - Step 8 - Current State 106 - vbar = 9.15
# 		Decision=107, vhat 16.05 and new vbar for current state 16.05
# 		 Theta 1.0  - Iteration 26 - Step 9 - Current State 107 - vbar = 14.89
# 		Decision=108, vhat 9.14 and new vbar for current state 9.14
# 		 Theta 1.0  - Iteration 26 - Step 10 - Current State 108 - vbar = 4.16
# 		Decision=109, vhat 2.80 and new vbar for current state 2.80
# Finishing Theta 1.0 and Iteration 26 with 10 steps. Total cost: 41.98735567094924
#
# 	Theta 1.0  - Iteration 27 - Stepsize 1.00 - InitState 1 - Vbar 47.40
# 		 Theta 1.0  - Iteration 27 - Step 1 - Current State 1 - vbar = 47.40
# 		Decision=51, vhat 50.12 and new vbar for current state 50.12
# 		 Theta 1.0  - Iteration 27 - Step 2 - Current State 51 - vbar = 45.54
# 		Decision=52, vhat 45.90 and new vbar for current state 45.90
# 		 Theta 1.0  - Iteration 27 - Step 3 - Current State 52 - vbar = 35.41
# 		Decision=53, vhat 35.89 and new vbar for current state 35.89
# 		 Theta 1.0  - Iteration 27 - Step 4 - Current State 53 - vbar = 33.83
# 		Decision=120, vhat 30.51 and new vbar for current state 30.51
# 		 Theta 1.0  - Iteration 27 - Step 5 - Current State 120 - vbar = 19.03
# 		Decision=28, vhat 23.34 and new vbar for current state 23.34
# 		 Theta 1.0  - Iteration 27 - Step 6 - Current State 28 - vbar = 20.58
# 		Decision=91, vhat 18.18 and new vbar for current state 18.18
# 		 Theta 1.0  - Iteration 27 - Step 7 - Current State 91 - vbar = 12.60
# 		Decision=106, vhat 18.91 and new vbar for current state 18.91
# 		 Theta 1.0  - Iteration 27 - Step 8 - Current State 106 - vbar = 16.05
# 		Decision=107, vhat 10.10 and new vbar for current state 10.10
# 		 Theta 1.0  - Iteration 27 - Step 9 - Current State 107 - vbar = 9.14
# 		Decision=108, vhat 8.42 and new vbar for current state 8.42
# 		 Theta 1.0  - Iteration 27 - Step 10 - Current State 108 - vbar = 2.80
# 		Decision=109, vhat 9.25 and new vbar for current state 9.25
# Finishing Theta 1.0 and Iteration 27 with 10 steps. Total cost: 55.64649972793871
#
# 	Theta 1.0  - Iteration 28 - Stepsize 1.00 - InitState 1 - Vbar 50.12
# 		 Theta 1.0  - Iteration 28 - Step 1 - Current State 1 - vbar = 50.12
# 		Decision=51, vhat 50.48 and new vbar for current state 50.48
# 		 Theta 1.0  - Iteration 28 - Step 2 - Current State 51 - vbar = 45.90
# 		Decision=52, vhat 44.12 and new vbar for current state 44.12
# 		 Theta 1.0  - Iteration 28 - Step 3 - Current State 52 - vbar = 35.89
# 		Decision=53, vhat 32.09 and new vbar for current state 32.09
# 		 Theta 1.0  - Iteration 28 - Step 4 - Current State 53 - vbar = 30.51
# 		Decision=120, vhat 32.11 and new vbar for current state 32.11
# 		 Theta 1.0  - Iteration 28 - Step 5 - Current State 120 - vbar = 23.34
# 		Decision=28, vhat 19.76 and new vbar for current state 19.76
# 		 Theta 1.0  - Iteration 28 - Step 6 - Current State 28 - vbar = 18.18
# 		Decision=91, vhat 23.86 and new vbar for current state 23.86
# 		 Theta 1.0  - Iteration 28 - Step 7 - Current State 91 - vbar = 18.91
# 		Decision=106, vhat 12.78 and new vbar for current state 12.78
# 		 Theta 1.0  - Iteration 28 - Step 8 - Current State 106 - vbar = 10.10
# 		Decision=107, vhat 9.64 and new vbar for current state 9.64
# 		 Theta 1.0  - Iteration 28 - Step 9 - Current State 107 - vbar = 8.42
# 		Decision=108, vhat 14.56 and new vbar for current state 14.56
# 		 Theta 1.0  - Iteration 28 - Step 10 - Current State 108 - vbar = 9.25
# 		Decision=109, vhat 8.70 and new vbar for current state 8.70
# Finishing Theta 1.0 and Iteration 28 with 10 steps. Total cost: 47.59687203105593
#
# 	Theta 1.0  - Iteration 29 - Stepsize 1.00 - InitState 1 - Vbar 50.48
# 		 Theta 1.0  - Iteration 29 - Step 1 - Current State 1 - vbar = 50.48
# 		Decision=51, vhat 48.70 and new vbar for current state 48.70
# 		 Theta 1.0  - Iteration 29 - Step 2 - Current State 51 - vbar = 44.12
# 		Decision=52, vhat 39.84 and new vbar for current state 39.84
# 		 Theta 1.0  - Iteration 29 - Step 3 - Current State 52 - vbar = 32.09
# 		Decision=53, vhat 33.25 and new vbar for current state 33.25
# 		 Theta 1.0  - Iteration 29 - Step 4 - Current State 53 - vbar = 32.11
# 		Decision=120, vhat 27.17 and new vbar for current state 27.17
# 		 Theta 1.0  - Iteration 29 - Step 5 - Current State 120 - vbar = 19.76
# 		Decision=28, vhat 28.21 and new vbar for current state 28.21
# 		 Theta 1.0  - Iteration 29 - Step 6 - Current State 28 - vbar = 23.86
# 		Decision=91, vhat 17.77 and new vbar for current state 17.77
# 		 Theta 1.0  - Iteration 29 - Step 7 - Current State 91 - vbar = 12.78
# 		Decision=106, vhat 12.76 and new vbar for current state 12.76
# 		 Theta 1.0  - Iteration 29 - Step 8 - Current State 106 - vbar = 9.64
# 		Decision=107, vhat 15.77 and new vbar for current state 15.77
# 		 Theta 1.0  - Iteration 29 - Step 9 - Current State 107 - vbar = 14.56
# 		Decision=108, vhat 13.69 and new vbar for current state 13.69
# 		 Theta 1.0  - Iteration 29 - Step 10 - Current State 108 - vbar = 8.70
# 		Decision=109, vhat 2.24 and new vbar for current state 2.24
# Finishing Theta 1.0 and Iteration 29 with 10 steps. Total cost: 41.77592620506756
#
# 	Theta 1.0  - Iteration 30 - Stepsize 1.00 - InitState 1 - Vbar 48.70
# 		 Theta 1.0  - Iteration 30 - Step 1 - Current State 1 - vbar = 48.70
# 		Decision=51, vhat 44.42 and new vbar for current state 44.42
# 		 Theta 1.0  - Iteration 30 - Step 2 - Current State 51 - vbar = 39.84
# 		Decision=52, vhat 42.93 and new vbar for current state 42.93
# 		 Theta 1.0  - Iteration 30 - Step 3 - Current State 52 - vbar = 33.25
# 		Decision=53, vhat 29.31 and new vbar for current state 29.31
# 		 Theta 1.0  - Iteration 30 - Step 4 - Current State 53 - vbar = 27.17
# 		Decision=120, vhat 39.83 and new vbar for current state 39.83
# 		 Theta 1.0  - Iteration 30 - Step 5 - Current State 120 - vbar = 28.21
# 		Decision=28, vhat 21.45 and new vbar for current state 21.45
# 		 Theta 1.0  - Iteration 30 - Step 6 - Current State 28 - vbar = 17.77
# 		Decision=91, vhat 17.95 and new vbar for current state 17.95
# 		 Theta 1.0  - Iteration 30 - Step 7 - Current State 91 - vbar = 12.76
# 		Decision=106, vhat 19.44 and new vbar for current state 19.44
# 		 Theta 1.0  - Iteration 30 - Step 8 - Current State 106 - vbar = 15.77
# 		Decision=107, vhat 14.59 and new vbar for current state 14.59
# 		 Theta 1.0  - Iteration 30 - Step 9 - Current State 107 - vbar = 13.69
# 		Decision=108, vhat 7.31 and new vbar for current state 7.31
# 		 Theta 1.0  - Iteration 30 - Step 10 - Current State 108 - vbar = 2.24
# 		Decision=109, vhat 5.11 and new vbar for current state 5.11
# Finishing Theta 1.0 and Iteration 30 with 10 steps. Total cost: 51.6560648363557
#
# 	Theta 1.0  - Iteration 31 - Stepsize 1.00 - InitState 1 - Vbar 44.42
# 		 Theta 1.0  - Iteration 31 - Step 1 - Current State 1 - vbar = 44.42
# 		Decision=51, vhat 47.51 and new vbar for current state 47.51
# 		 Theta 1.0  - Iteration 31 - Step 2 - Current State 51 - vbar = 42.93
# 		Decision=52, vhat 38.43 and new vbar for current state 38.43
# 		 Theta 1.0  - Iteration 31 - Step 3 - Current State 52 - vbar = 29.31
# 		Decision=53, vhat 41.72 and new vbar for current state 41.72
# 		 Theta 1.0  - Iteration 31 - Step 4 - Current State 53 - vbar = 39.83
# 		Decision=120, vhat 29.41 and new vbar for current state 29.41
# 		 Theta 1.0  - Iteration 31 - Step 5 - Current State 120 - vbar = 21.45
# 		Decision=28, vhat 18.46 and new vbar for current state 18.46
# 		 Theta 1.0  - Iteration 31 - Step 6 - Current State 28 - vbar = 17.95
# 		Decision=91, vhat 24.91 and new vbar for current state 24.91
# 		 Theta 1.0  - Iteration 31 - Step 7 - Current State 91 - vbar = 19.44
# 		Decision=106, vhat 17.69 and new vbar for current state 17.69
# 		 Theta 1.0  - Iteration 31 - Step 8 - Current State 106 - vbar = 14.59
# 		Decision=107, vhat 8.36 and new vbar for current state 8.36
# 		 Theta 1.0  - Iteration 31 - Step 9 - Current State 107 - vbar = 7.31
# 		Decision=108, vhat 10.55 and new vbar for current state 10.55
# 		 Theta 1.0  - Iteration 31 - Step 10 - Current State 108 - vbar = 5.11
# 		Decision=109, vhat 5.32 and new vbar for current state 5.32
# Finishing Theta 1.0 and Iteration 31 with 10 steps. Total cost: 44.43115687822818
#
# 	Theta 1.0  - Iteration 32 - Stepsize 1.00 - InitState 1 - Vbar 47.51
# 		 Theta 1.0  - Iteration 32 - Step 1 - Current State 1 - vbar = 47.51
# 		Decision=51, vhat 43.01 and new vbar for current state 43.01
# 		 Theta 1.0  - Iteration 32 - Step 2 - Current State 51 - vbar = 38.43
# 		Decision=24, vhat 49.69 and new vbar for current state 49.69
# 		 Theta 1.0  - Iteration 32 - Step 3 - Current State 24 - vbar = 43.72
# 		Decision=25, vhat 45.04 and new vbar for current state 45.04
# 		 Theta 1.0  - Iteration 32 - Step 4 - Current State 25 - vbar = 34.85
# 		Decision=26, vhat 31.96 and new vbar for current state 31.96
# 		 Theta 1.0  - Iteration 32 - Step 5 - Current State 26 - vbar = 27.55
# 		Decision=27, vhat 27.43 and new vbar for current state 27.43
# 		 Theta 1.0  - Iteration 32 - Step 6 - Current State 27 - vbar = 24.02
# 		Decision=28, vhat 28.41 and new vbar for current state 28.41
# 		 Theta 1.0  - Iteration 32 - Step 7 - Current State 28 - vbar = 24.91
# 		Decision=91, vhat 23.17 and new vbar for current state 23.17
# 		 Theta 1.0  - Iteration 32 - Step 8 - Current State 91 - vbar = 17.69
# 		Decision=106, vhat 11.66 and new vbar for current state 11.66
# 		 Theta 1.0  - Iteration 32 - Step 9 - Current State 106 - vbar = 8.36
# 		Decision=107, vhat 11.43 and new vbar for current state 11.43
# ...
# 		Decision=28, vhat 21.41 and new vbar for current state 22.87
# 		 Theta 0.1  - Iteration 90 - Step 6 - Current State 28 - vbar = 20.47
# 		Decision=91, vhat 20.52 and new vbar for current state 20.48
# 		 Theta 0.1  - Iteration 90 - Step 7 - Current State 91 - vbar = 15.20
# 		Decision=106, vhat 15.21 and new vbar for current state 15.20
# 		 Theta 0.1  - Iteration 90 - Step 8 - Current State 106 - vbar = 11.78
# 		Decision=107, vhat 11.95 and new vbar for current state 11.80
# 		 Theta 0.1  - Iteration 90 - Step 9 - Current State 107 - vbar = 10.71
# 		Decision=108, vhat 9.67 and new vbar for current state 10.61
# 		 Theta 0.1  - Iteration 90 - Step 10 - Current State 108 - vbar = 4.64
# 		Decision=109, vhat 6.96 and new vbar for current state 4.88
# Finishing Theta 0.1 and Iteration 90 with 10 steps. Total cost: 46.735255236277304
#
# 	Theta 0.1  - Iteration 91 - Stepsize 0.10 - InitState 1 - Vbar 47.51
# 		 Theta 0.1  - Iteration 91 - Step 1 - Current State 1 - vbar = 47.51
# 		Decision=51, vhat 47.67 and new vbar for current state 47.53
# 		 Theta 0.1  - Iteration 91 - Step 2 - Current State 51 - vbar = 43.09
# 		Decision=52, vhat 43.21 and new vbar for current state 43.10
# 		 Theta 0.1  - Iteration 91 - Step 3 - Current State 52 - vbar = 33.55
# 		Decision=53, vhat 33.92 and new vbar for current state 33.59
# 		 Theta 0.1  - Iteration 91 - Step 4 - Current State 53 - vbar = 32.13
# 		Decision=120, vhat 32.59 and new vbar for current state 32.18
# 		 Theta 0.1  - Iteration 91 - Step 5 - Current State 120 - vbar = 22.87
# 		Decision=28, vhat 21.74 and new vbar for current state 22.75
# 		 Theta 0.1  - Iteration 91 - Step 6 - Current State 28 - vbar = 20.48
# 		Decision=91, vhat 20.30 and new vbar for current state 20.46
# 		 Theta 0.1  - Iteration 91 - Step 7 - Current State 91 - vbar = 15.20
# 		Decision=106, vhat 15.55 and new vbar for current state 15.23
# 		 Theta 0.1  - Iteration 91 - Step 8 - Current State 106 - vbar = 11.80
# 		Decision=107, vhat 11.76 and new vbar for current state 11.79
# 		 Theta 0.1  - Iteration 91 - Step 9 - Current State 107 - vbar = 10.61
# 		Decision=108, vhat 10.75 and new vbar for current state 10.62
# 		 Theta 0.1  - Iteration 91 - Step 10 - Current State 108 - vbar = 4.88
# 		Decision=109, vhat 6.85 and new vbar for current state 5.07
# Finishing Theta 0.1 and Iteration 91 with 10 steps. Total cost: 49.741349717041274
#
# 	Theta 0.1  - Iteration 92 - Stepsize 0.10 - InitState 1 - Vbar 47.53
# 		 Theta 0.1  - Iteration 92 - Step 1 - Current State 1 - vbar = 47.53
# 		Decision=51, vhat 47.68 and new vbar for current state 47.54
# 		 Theta 0.1  - Iteration 92 - Step 2 - Current State 51 - vbar = 43.10
# 		Decision=52, vhat 43.23 and new vbar for current state 43.11
# 		 Theta 0.1  - Iteration 92 - Step 3 - Current State 52 - vbar = 33.59
# 		Decision=53, vhat 33.02 and new vbar for current state 33.53
# 		 Theta 0.1  - Iteration 92 - Step 4 - Current State 53 - vbar = 32.18
# 		Decision=120, vhat 29.71 and new vbar for current state 31.93
# 		 Theta 0.1  - Iteration 92 - Step 5 - Current State 120 - vbar = 22.75
# 		Decision=28, vhat 24.30 and new vbar for current state 22.91
# 		 Theta 0.1  - Iteration 92 - Step 6 - Current State 28 - vbar = 20.46
# 		Decision=91, vhat 20.75 and new vbar for current state 20.49
# 		 Theta 0.1  - Iteration 92 - Step 7 - Current State 91 - vbar = 15.23
# 		Decision=106, vhat 15.50 and new vbar for current state 15.26
# 		 Theta 0.1  - Iteration 92 - Step 8 - Current State 106 - vbar = 11.79
# 		Decision=107, vhat 11.55 and new vbar for current state 11.77
# 		 Theta 0.1  - Iteration 92 - Step 9 - Current State 107 - vbar = 10.62
# 		Decision=108, vhat 10.44 and new vbar for current state 10.60
# 		 Theta 0.1  - Iteration 92 - Step 10 - Current State 108 - vbar = 5.07
# 		Decision=109, vhat 8.09 and new vbar for current state 5.37
# Finishing Theta 0.1 and Iteration 92 with 10 steps. Total cost: 49.475653505204036
#
# 	Theta 0.1  - Iteration 93 - Stepsize 0.10 - InitState 1 - Vbar 47.54
# 		 Theta 0.1  - Iteration 93 - Step 1 - Current State 1 - vbar = 47.54
# 		Decision=51, vhat 47.69 and new vbar for current state 47.56
# 		 Theta 0.1  - Iteration 93 - Step 2 - Current State 51 - vbar = 43.11
# 		Decision=52, vhat 44.87 and new vbar for current state 43.29
# 		 Theta 0.1  - Iteration 93 - Step 3 - Current State 52 - vbar = 33.53
# 		Decision=53, vhat 33.87 and new vbar for current state 33.56
# 		 Theta 0.1  - Iteration 93 - Step 4 - Current State 53 - vbar = 31.93
# 		Decision=120, vhat 32.82 and new vbar for current state 32.02
# 		 Theta 0.1  - Iteration 93 - Step 5 - Current State 120 - vbar = 22.91
# 		Decision=28, vhat 21.98 and new vbar for current state 22.81
# 		 Theta 0.1  - Iteration 93 - Step 6 - Current State 28 - vbar = 20.49
# 		Decision=91, vhat 20.73 and new vbar for current state 20.51
# 		 Theta 0.1  - Iteration 93 - Step 7 - Current State 91 - vbar = 15.26
# 		Decision=106, vhat 15.49 and new vbar for current state 15.28
# 		 Theta 0.1  - Iteration 93 - Step 8 - Current State 106 - vbar = 11.77
# 		Decision=107, vhat 11.79 and new vbar for current state 11.77
# 		 Theta 0.1  - Iteration 93 - Step 9 - Current State 107 - vbar = 10.60
# 		Decision=108, vhat 10.87 and new vbar for current state 10.63
# 		 Theta 0.1  - Iteration 93 - Step 10 - Current State 108 - vbar = 5.37
# 		Decision=109, vhat 2.05 and new vbar for current state 5.04
# Finishing Theta 0.1 and Iteration 93 with 10 steps. Total cost: 47.17130987975618
#
# 	Theta 0.1  - Iteration 94 - Stepsize 0.10 - InitState 1 - Vbar 47.56
# 		 Theta 0.1  - Iteration 94 - Step 1 - Current State 1 - vbar = 47.56
# 		Decision=51, vhat 47.87 and new vbar for current state 47.59
# 		 Theta 0.1  - Iteration 94 - Step 2 - Current State 51 - vbar = 43.29
# 		Decision=52, vhat 44.11 and new vbar for current state 43.37
# 		 Theta 0.1  - Iteration 94 - Step 3 - Current State 52 - vbar = 33.56
# 		Decision=53, vhat 32.82 and new vbar for current state 33.49
# 		 Theta 0.1  - Iteration 94 - Step 4 - Current State 53 - vbar = 32.02
# 		Decision=120, vhat 32.83 and new vbar for current state 32.10
# 		 Theta 0.1  - Iteration 94 - Step 5 - Current State 120 - vbar = 22.81
# 		Decision=28, vhat 24.60 and new vbar for current state 22.99
# 		 Theta 0.1  - Iteration 94 - Step 6 - Current State 28 - vbar = 20.51
# 		Decision=91, vhat 20.56 and new vbar for current state 20.52
# 		 Theta 0.1  - Iteration 94 - Step 7 - Current State 91 - vbar = 15.28
# 		Decision=106, vhat 15.28 and new vbar for current state 15.28
# 		 Theta 0.1  - Iteration 94 - Step 8 - Current State 106 - vbar = 11.77
# 		Decision=107, vhat 11.97 and new vbar for current state 11.79
# 		 Theta 0.1  - Iteration 94 - Step 9 - Current State 107 - vbar = 10.63
# 		Decision=108, vhat 10.36 and new vbar for current state 10.60
# 		 Theta 0.1  - Iteration 94 - Step 10 - Current State 108 - vbar = 5.04
# 		Decision=109, vhat 3.92 and new vbar for current state 4.93
# Finishing Theta 0.1 and Iteration 94 with 10 steps. Total cost: 49.38861822890852
#
# 	Theta 0.1  - Iteration 95 - Stepsize 0.10 - InitState 1 - Vbar 47.59
# 		 Theta 0.1  - Iteration 95 - Step 1 - Current State 1 - vbar = 47.59
# 		Decision=51, vhat 47.95 and new vbar for current state 47.62
# 		 Theta 0.1  - Iteration 95 - Step 2 - Current State 51 - vbar = 43.37
# 		Decision=52, vhat 43.11 and new vbar for current state 43.35
# 		 Theta 0.1  - Iteration 95 - Step 3 - Current State 52 - vbar = 33.49
# 		Decision=53, vhat 34.02 and new vbar for current state 33.54
# 		 Theta 0.1  - Iteration 95 - Step 4 - Current State 53 - vbar = 32.10
# 		Decision=120, vhat 32.50 and new vbar for current state 32.14
# 		 Theta 0.1  - Iteration 95 - Step 5 - Current State 120 - vbar = 22.99
# 		Decision=28, vhat 21.18 and new vbar for current state 22.81
# 		 Theta 0.1  - Iteration 95 - Step 6 - Current State 28 - vbar = 20.52
# 		Decision=91, vhat 20.69 and new vbar for current state 20.54
# 		 Theta 0.1  - Iteration 95 - Step 7 - Current State 91 - vbar = 15.28
# 		Decision=106, vhat 15.22 and new vbar for current state 15.28
# 		 Theta 0.1  - Iteration 95 - Step 8 - Current State 106 - vbar = 11.79
# 		Decision=107, vhat 11.45 and new vbar for current state 11.76
# 		 Theta 0.1  - Iteration 95 - Step 9 - Current State 107 - vbar = 10.60
# 		Decision=108, vhat 10.22 and new vbar for current state 10.56
# 		 Theta 0.1  - Iteration 95 - Step 10 - Current State 108 - vbar = 4.93
# 		Decision=109, vhat 5.42 and new vbar for current state 4.98
# Finishing Theta 0.1 and Iteration 95 with 10 steps. Total cost: 46.6759259241134
#
# 	Theta 0.1  - Iteration 96 - Stepsize 0.10 - InitState 1 - Vbar 47.62
# 		 Theta 0.1  - Iteration 96 - Step 1 - Current State 1 - vbar = 47.62
# 		Decision=51, vhat 47.92 and new vbar for current state 47.65
# 		 Theta 0.1  - Iteration 96 - Step 2 - Current State 51 - vbar = 43.35
# 		Decision=52, vhat 41.34 and new vbar for current state 43.14
# 		 Theta 0.1  - Iteration 96 - Step 3 - Current State 52 - vbar = 33.54
# 		Decision=53, vhat 33.58 and new vbar for current state 33.55
# 		 Theta 0.1  - Iteration 96 - Step 4 - Current State 53 - vbar = 32.14
# 		Decision=120, vhat 32.69 and new vbar for current state 32.20
# 		 Theta 0.1  - Iteration 96 - Step 5 - Current State 120 - vbar = 22.81
# 		Decision=28, vhat 22.07 and new vbar for current state 22.74
# 		 Theta 0.1  - Iteration 96 - Step 6 - Current State 28 - vbar = 20.54
# 		Decision=91, vhat 20.31 and new vbar for current state 20.51
# 		 Theta 0.1  - Iteration 96 - Step 7 - Current State 91 - vbar = 15.28
# 		Decision=106, vhat 14.63 and new vbar for current state 15.21
# 		 Theta 0.1  - Iteration 96 - Step 8 - Current State 106 - vbar = 11.76
# 		Decision=107, vhat 11.60 and new vbar for current state 11.74
# 		 Theta 0.1  - Iteration 96 - Step 9 - Current State 107 - vbar = 10.56
# 		Decision=108, vhat 10.04 and new vbar for current state 10.51
# 		 Theta 0.1  - Iteration 96 - Step 10 - Current State 108 - vbar = 4.98
# 		Decision=109, vhat 3.35 and new vbar for current state 4.82
# Finishing Theta 0.1 and Iteration 96 with 10 steps. Total cost: 42.56411973796824
#
# 	Theta 0.1  - Iteration 97 - Stepsize 0.10 - InitState 1 - Vbar 47.65
# 		 Theta 0.1  - Iteration 97 - Step 1 - Current State 1 - vbar = 47.65
# 		Decision=51, vhat 47.72 and new vbar for current state 47.66
# 		 Theta 0.1  - Iteration 97 - Step 2 - Current State 51 - vbar = 43.14
# 		Decision=52, vhat 42.40 and new vbar for current state 43.07
# 		 Theta 0.1  - Iteration 97 - Step 3 - Current State 52 - vbar = 33.55
# 		Decision=53, vhat 33.27 and new vbar for current state 33.52
# 		 Theta 0.1  - Iteration 97 - Step 4 - Current State 53 - vbar = 32.20
# 		Decision=120, vhat 32.70 and new vbar for current state 32.25
# 		 Theta 0.1  - Iteration 97 - Step 5 - Current State 120 - vbar = 22.74
# 		Decision=28, vhat 24.59 and new vbar for current state 22.92
# 		 Theta 0.1  - Iteration 97 - Step 6 - Current State 28 - vbar = 20.51
# 		Decision=91, vhat 20.72 and new vbar for current state 20.53
# 		 Theta 0.1  - Iteration 97 - Step 7 - Current State 91 - vbar = 15.21
# 		Decision=106, vhat 15.33 and new vbar for current state 15.22
# 		 Theta 0.1  - Iteration 97 - Step 8 - Current State 106 - vbar = 11.74
# 		Decision=107, vhat 11.51 and new vbar for current state 11.72
# 		 Theta 0.1  - Iteration 97 - Step 9 - Current State 107 - vbar = 10.51
# 		Decision=108, vhat 10.60 and new vbar for current state 10.52
# 		 Theta 0.1  - Iteration 97 - Step 10 - Current State 108 - vbar = 4.82
# 		Decision=109, vhat 9.10 and new vbar for current state 5.24
# Finishing Theta 0.1 and Iteration 97 with 10 steps. Total cost: 53.541024968394666
#
# 	Theta 0.1  - Iteration 98 - Stepsize 0.10 - InitState 1 - Vbar 47.66
# 		 Theta 0.1  - Iteration 98 - Step 1 - Current State 1 - vbar = 47.66
# 		Decision=51, vhat 47.65 and new vbar for current state 47.66
# 		 Theta 0.1  - Iteration 98 - Step 2 - Current State 51 - vbar = 43.07
# 		Decision=52, vhat 41.25 and new vbar for current state 42.89
# 		 Theta 0.1  - Iteration 98 - Step 3 - Current State 52 - vbar = 33.52
# 		Decision=53, vhat 33.98 and new vbar for current state 33.56
# 		 Theta 0.1  - Iteration 98 - Step 4 - Current State 53 - vbar = 32.25
# 		Decision=120, vhat 29.90 and new vbar for current state 32.01
# 		 Theta 0.1  - Iteration 98 - Step 5 - Current State 120 - vbar = 22.92
# 		Decision=28, vhat 22.49 and new vbar for current state 22.88
# 		 Theta 0.1  - Iteration 98 - Step 6 - Current State 28 - vbar = 20.53
# 		Decision=91, vhat 20.43 and new vbar for current state 20.52
# 		 Theta 0.1  - Iteration 98 - Step 7 - Current State 91 - vbar = 15.22
# 		Decision=106, vhat 14.88 and new vbar for current state 15.19
# 		 Theta 0.1  - Iteration 98 - Step 8 - Current State 106 - vbar = 11.72
# 		Decision=107, vhat 11.40 and new vbar for current state 11.69
# 		 Theta 0.1  - Iteration 98 - Step 9 - Current State 107 - vbar = 10.52
# 		Decision=108, vhat 10.32 and new vbar for current state 10.50
# 		 Theta 0.1  - Iteration 98 - Step 10 - Current State 108 - vbar = 5.24
# 		Decision=109, vhat 2.20 and new vbar for current state 4.94
# Finishing Theta 0.1 and Iteration 98 with 10 steps. Total cost: 39.495433298149656
#
# 	Theta 0.1  - Iteration 99 - Stepsize 0.10 - InitState 1 - Vbar 47.66
# 		 Theta 0.1  - Iteration 99 - Step 1 - Current State 1 - vbar = 47.66
# 		Decision=51, vhat 47.47 and new vbar for current state 47.64
# 		 Theta 0.1  - Iteration 99 - Step 2 - Current State 51 - vbar = 42.89
# 		Decision=52, vhat 42.45 and new vbar for current state 42.84
# 		 Theta 0.1  - Iteration 99 - Step 3 - Current State 52 - vbar = 33.56
# 		Decision=53, vhat 33.29 and new vbar for current state 33.54
# 		 Theta 0.1  - Iteration 99 - Step 4 - Current State 53 - vbar = 32.01
# 		Decision=120, vhat 30.63 and new vbar for current state 31.87
# 		 Theta 0.1  - Iteration 99 - Step 5 - Current State 120 - vbar = 22.88
# 		Decision=28, vhat 25.19 and new vbar for current state 23.11
# 		 Theta 0.1  - Iteration 99 - Step 6 - Current State 28 - vbar = 20.52
# 		Decision=91, vhat 20.60 and new vbar for current state 20.53
# 		 Theta 0.1  - Iteration 99 - Step 7 - Current State 91 - vbar = 15.19
# 		Decision=106, vhat 15.33 and new vbar for current state 15.20
# 		 Theta 0.1  - Iteration 99 - Step 8 - Current State 106 - vbar = 11.69
# 		Decision=107, vhat 11.42 and new vbar for current state 11.66
# 		 Theta 0.1  - Iteration 99 - Step 9 - Current State 107 - vbar = 10.50
# 		Decision=108, vhat 11.01 and new vbar for current state 10.55
# 		 Theta 0.1  - Iteration 99 - Step 10 - Current State 108 - vbar = 4.94
# 		Decision=109, vhat 8.46 and new vbar for current state 5.29
# Finishing Theta 0.1 and Iteration 99 with 10 steps. Total cost: 51.664674239853824
#
# 	Theta 0.1  - Iteration 100 - Stepsize 0.10 - InitState 1 - Vbar 47.64
# 		 Theta 0.1  - Iteration 100 - Step 1 - Current State 1 - vbar = 47.64
# 		Decision=51, vhat 47.42 and new vbar for current state 47.62
# 		 Theta 0.1  - Iteration 100 - Step 2 - Current State 51 - vbar = 42.84
# 		Decision=52, vhat 44.47 and new vbar for current state 43.01
# 		 Theta 0.1  - Iteration 100 - Step 3 - Current State 52 - vbar = 33.54
# 		Decision=53, vhat 33.48 and new vbar for current state 33.53
# 		 Theta 0.1  - Iteration 100 - Step 4 - Current State 53 - vbar = 31.87
# 		Decision=120, vhat 30.36 and new vbar for current state 31.72
# 		 Theta 0.1  - Iteration 100 - Step 5 - Current State 120 - vbar = 23.11
# 		Decision=28, vhat 23.23 and new vbar for current state 23.12
# 		 Theta 0.1  - Iteration 100 - Step 6 - Current State 28 - vbar = 20.53
# 		Decision=91, vhat 20.75 and new vbar for current state 20.55
# 		 Theta 0.1  - Iteration 100 - Step 7 - Current State 91 - vbar = 15.20
# 		Decision=106, vhat 14.38 and new vbar for current state 15.12
# 		 Theta 0.1  - Iteration 100 - Step 8 - Current State 106 - vbar = 11.66
# 		Decision=107, vhat 11.61 and new vbar for current state 11.65
# 		 Theta 0.1  - Iteration 100 - Step 9 - Current State 107 - vbar = 10.55
# 		Decision=108, vhat 11.02 and new vbar for current state 10.60
# 		 Theta 0.1  - Iteration 100 - Step 10 - Current State 108 - vbar = 5.29
# 		Decision=109, vhat 4.46 and new vbar for current state 5.21
# Finishing Theta 0.1 and Iteration 100 with 10 steps. Total cost: 46.56696430965737

# %%
#Ploting the results
fig1, axsubs = plt.subplots(1,2)
fig1.suptitle('Comparison of theta^step - stepsize type {} - origin {}, target {}, dist {} '.format(M.init_args['stepsize_rule'],M.origin_node,M.target_node,M.dist) )
  
color_list = ['b','g','r','m','c']
nThetas = list(range(len(theta_list)))
Iterations = list(range(model.init_args['nIterations']))

    
totals = [np.array(obj_along_iterations[theta]).sum() for theta in theta_list]
print("Totals ",totals)


for theta,t in zip(theta_list,nThetas):
        
        axsubs[0].plot(Iterations, np.array(obj_along_iterations[theta]).cumsum(), "{}-".format(color_list[t]),label = "{}".format(theta))
        #axsubs[0].plot(Iterations, obj_along_iterations[theta], "{}-".format(color_list[t]),label = "{}".format(theta))

        axsubs[0].set_title('Objective function')
        axsubs[0].legend()
        axsubs[0].set_xlabel('Iterations')
        axsubs[0].set_ylabel('Cost')

        axsubs[1].plot(Iterations, vbar_along_iterations[theta], "{}o-".format(color_list[t]),label = "{}".format(theta))
        axsubs[1].set_title('Vbar')
        axsubs[1].legend()
        axsubs[1].set_xlabel('Iterations')
        axsubs[1].set_ylabel('Cost')


        #axsubs.plot(Iterations, obj_along_iterations[theta], "{}o-".format(color_list[t]),label = "{}".format(theta))
        #axsubs[0].set_title('Cost')
        #axsubs.legend()
        #axsubs.set_xlabel('Iterations')
        #axsubs.set_ylabel('Cost')

plt.show()
# Out:
# Totals  [4831.688380812283, 4763.680134579409, 4763.680134579409, 4763.680134579409]
